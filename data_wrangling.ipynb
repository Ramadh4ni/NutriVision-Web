# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramadh4ni/NutriVision-Web/blob/main/data_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("NutriVision Data Wrangling 🚀")
# Out:
# NutriVision Data Wrangling 🚀
